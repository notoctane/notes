# %%
import requests
from lxml import etree

url = 'https://www.rudn.ru/education/schedule'
schedule = requests.get(url)

''' Преобразуем html в xml'''
parser = etree.HTMLParser()
schedule_root = etree.fromstring(schedule.text, parser)

# %%
schedule_facultets = []
