# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

class feature_diagnostic:
    def __init__(self, X, y):
        self.X = X
        self.y = y
    def box_plots(self):
        sns.boxplot(self.X.appe)
# Out:
#   Cell In[3], line 6
#     class feature_diagnostic(features=pd.DataFrame())->plt.show():
#                                                      ^
# SyntaxError: invalid syntax
